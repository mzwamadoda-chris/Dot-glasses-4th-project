# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\\Users\somel\\Downloads\\Dots Potential Customer Survey Data - Sheet1.csv")

# %%
k = 10 #number of variables for heatmap
cols = df.corr().nlargest(k, 'Wear Specs')['Wear Specs'].index
cm = dot_glass[cols].corr()
plt.figure(figsize=(10,6))
sns.heatmap(cm, annot=True, cmap = 'viridis')
# Out:
# <Axes: >

# %%
final_dot_glass = df[['Annual Family Income ($)','Age','Drinks alcohol','Time spent watching videos/TV','Country_KOR','Wants to change career','Total Time spent working in front of screen','IQ','Has Diabetes']]

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Has Diabetes', hue='Wear Specs')
plt.title('Count Plot of Wear Specs vs Has Diabetes')
plt.xlabel('Has Diabetes')
plt.ylabel('Count')
plt.legend(title='Wear Specs', loc='upper right')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='Wear Specs', y='Time spent watching videos/TV')
plt.title('Box Plot of Time spent watching TV/videos by Wear Specs')
plt.xlabel('Wear Specs')
plt.ylabel('Time spent watching TV/videos')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data= df, x='Drinks alcohol', hue='Wear Specs')
plt.title('Count Plot of Wear Specs vs Drinks alcohol')
plt.xlabel('Drinks alcohol')
plt.ylabel('Count')
plt.legend(title='Wear Specs', loc='upper right')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data= df, x='Whether parents have specs', hue='Wear Specs')
plt.title('Count Plot of Wear Specs vs Whether parents have specs')
plt.xlabel('Whether parents have specs')
plt.ylabel('Count')
plt.legend(title='Wear Specs', loc='upper right')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='Wear Specs', y='IQ')
plt.title('Box Plot of IQ by Wear Specs')
plt.xlabel('Wear Specs')
plt.ylabel('IQ')
plt.show()
